# %%
import main

main.OutputMR('Test_EOS.csv')
# Out:
# This is a valid equation of state
# Mass Radius file will be generated and stored as MassRadius.csv, and the 2-d array. The first column is Radoius, second one is mass
# array([[ 5.71291948e+01,  1.16715725e-01,  1.21221686e+10],
#        [ 3.79494223e+01,  1.15035419e-01,  1.19071489e+09],
#        [ 2.31049204e+01,  1.34692554e-01,  8.75344301e+07],
#        [ 1.74851046e+01,  1.70702943e-01,  3.15214871e+07],
#        [ 1.52871298e+01,  2.13584437e-01,  2.22682593e+07],
#        [ 1.41657651e+01,  2.65836152e-01,  3.72693103e+07],
#        [ 1.35833007e+01,  3.27079375e-01, -1.21845976e+07],
#        [ 1.32947870e+01,  3.97506464e-01, -2.43652632e+06],
#        [ 1.31939193e+01,  4.77011304e-01, -8.24285635e+05],
#        [ 1.31267444e+01,  5.65149256e-01, -3.38204863e+05],
#        [ 1.31757166e+01,  6.61112810e-01, -1.55463162e+05],
#        [ 1.32732578e+01,  7.63746844e-01, -7.76052693e+04],
#        [ 1.33386519e+01,  8.71588407e-01, -4.14315844e+04],
# ...
